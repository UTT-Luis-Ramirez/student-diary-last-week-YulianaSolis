# %% [markdown]
# ##**Diario**
# ###**TERMINO Y QUE SE?**
# ####**PROBABILIDAD:** Es una medida de la posibilidad de que ocurra un evento
# ####**DATO:** Son piezas de información que recogemos del mundo que nos rodea.
# ####**EVENTO:** Cualquier cosa que pueda suceder en una situación aleatoria.
# ####**TEORIA DE CONJUNTOS:** Nos ayuda a entender y trabajar con colecciones de objetos, llamados conjuntos.
# ####**AXIOMAS:** Son como las reglas básicas o fundamentos sobre los que construimos teorías matemáticas.
# ####**ESTADISTICA:** Se dedica a recoger, analizar y sacar conclusiones a partir de datos.
# ####**TEORIA DEL CAOS:** Se ocupa de sistemas que parecen desordenados y caóticos, pero que en realidad siguen reglas muy precisas.
# ####**ESTADISTICA DESCRIPTIVA:** se enfoca en resumir y describir datos para entenderlos mejor.
# ####**ESTADISTICA INFERENCIAL:** Permite hacer predicciones o generalizaciones sobre una población más grande a partir algunos datos.
# ####**TEORIA DEL CONJUNTO:** Estudia las propiedades y relaciones que forman un grupo/conjunto
# ####**POBLACION:** Es un grupo de elementos/personas que cumplen con ciertas caracteristicas especificas
# ####**MUESTRA:** Es un grupo representativo de la poblacion seleccionado para relizar un analisis de una poblacion mas grande, cumpliendo ciertos requisitos/caracteristicas.
# ####**MUESTREO:** Es la forma en la que se reliaza la muestra, se encarga de dividir poblaciones, conjuntos, etc.
# ####**MUESTREO ESTRATIFICADO:** Clasifica datos, personas y objetos en grupos o capas distintos. Se utiliza en combinación con otras herramientas de análisis de datos. Cuando se agrupan datos de diversas fuentes o categorías.
# ####***ARREGLOS:** Es una estructura de datos que almacenan multiples valores en una sola variable
#
#
# ---

# %% [markdown]
# ##**Medidas de lozalizacion**
# ###Son datos que sirve para indentificar ciertos conjuntos de datos Busca inditificar alguna caracteristica especifica, estos nos ayudan a indentificar tendencias centrales, dividir datos en parte, detectar valores extremos, tomar decisiones basadas en metricas tecnicas.
#
# ##**Medidas de tendencia central**
# ###Medidas estadísticas que pretenden resumir en un solo valor a un conjunto de valores. Representan un centro en torno al cual se encuentra ubicado el conjunto de los datos.
#
# ##**1-Media aritmetica**
# ###Para un conjuntos dado de numeros la medida mas conocida y utili del centro es la medida aritmetica.
#
# ##**2-La mediana**
# ###Es el valor que se encuentra en el medio de un conjunto de datos ordenados. Si el número de datos es impar, la mediana es el valor central. Si el número de datos es par, la mediana es el promedio de los dos valores centrales.
#
# ##**3-Media recortada**
# ###La media recortada se calcula eliminando un porcentaje fijo de los valores más pequeños y más grandes de un conjunto de datos, y luego calculando la media de los valores restantes. Esto ayuda a reducir el efecto de los valores extremos o atípicos.
#
# ##**4-Cuartiles**
# ###Los cuartiles dividen un conjunto de datos en cuatro partes iguales. Se utilizan para describir la distribución de los datos:
#
# ###Primer cuartil (Q1): El valor que divide el primer 25% de los datos.
#
# ###Segundo cuartil (Q2): El valor que divide el 50% de los datos y es equivalente a la mediana.
#
# ###Tercer cuartil (Q3): El valor que divide el 75% de los datos.
#
# ##**5-Precentiles**
# ###Los percentiles dividen un conjunto de datos en 100 partes iguales. El percentil 𝑝 indica el valor por debajo del cual se encuentra el 𝑝 % de los datos. Por ejemplo, el percentil 90 indica que el 90% de los datos son menores o iguales a ese valor.
#
# ##**6-Medidas de variabilidad**
# ###Los percentiles dividen un conjunto de datos en 100 partes iguales. El percentil 𝑝 indica el valor por debajo del cual se encuentra el 𝑝 % de los datos. Por ejemplo, el percentil 90 indica que el 90% de los datos son menores o iguales a ese valor.
#
# ##**Lenguaje latex**
# ###LaTeX es un sistema de preparación de documentos de alta calidad, especialmente útil para la creación de documentos científicos y técnicos que contienen fórmulas matemáticas complejas. Fue desarrollado por Leslie Lamport en la década de 1980 y se basa en el sistema de tipografía TeX creado por Donald Knuth.  Ejemplo: (solo agregar signos de dolar al inicio y final) La ecuación de segundo grado es:
# ##$$ ax^2 + bx + c = 0 $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)
